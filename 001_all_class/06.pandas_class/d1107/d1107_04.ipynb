# %%
import pandas as pd
df = pd.read_excel('score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  85      Python
# 2번    강태원  구로고  184   40   35   50  25        Java
# 3번    강호림  가산고  168   80   75   70  75  Javascript
# 4번    김수찬  구로고  187   40   60   70  80         NaN
# 5번    김재욱  가산고  188   15   20   10  10         NaN
# 6번    박동현  가산고  202   80  100   95  80           C
# 7번    박혜정  구로고  188   55   65   45  35      Python
# 8번    승근열  구로고  190  100   85   90  95          C#

# %%
df['이름']
df[['이름','학교','키']]
df[['키','이름','SW특기']]

df
# Out:
#         키   이름        SW특기
# 지원번호
# 1번    197  강나래      Python
# 2번    184  강태원        Java
# 3번    168  강호림  Javascript
# 4번    187  김수찬         NaN
# 5번    188  김재욱         NaN
# 6번    202  박동현           C
# 7번    188  박혜정      Python
# 8번    190  승근열          C#

# %%
df = pd.read_excel('score.xlsx',index_col='이름')
df
df.sort_index(ascending=False)
# Out:
#     지원번호   학교    키   국어   영어   수학  사회        SW특기
# 이름
# 승근열   8번  구로고  190  100   85   90  95          C#
# 박혜정   7번  구로고  188   55   65   45  35      Python
# 박동현   6번  가산고  202   80  100   95  80           C
# 김재욱   5번  가산고  188   15   20   10  10         NaN
# 김수찬   4번  구로고  187   40   60   70  80         NaN
# 강호림   3번  가산고  168   80   75   70  75  Javascript
# 강태원   2번  구로고  184   40   35   50  25        Java
# 강나래   1번  구로고  197   90   85  100  85      Python

# %%
df = pd.read_excel('score.xlsx',index_col='지원번호')
df
# 숫자에 해당되는 것만 출력
df.describe()
df['국어'].describe()
df['이름'].describe()
# Out:
# count       8
# unique      8
# top       강나래
# freq        1
# Name: 이름, dtype: object

# %%
df.head()
df.tail()
df.values
df.shape
df.columns
df['이름']
df.columns[-1]
df[df.columns[-1]]
df[df.columns[0]]
# df[0]  #df[번호] - 검색안됨
df[df.columns[0]]  # 1번째 컬럼 출력
df[df.columns[-1]] # 마지막 컬럼 출력

df.columns[0:3]  # 0,1,2 컬럼 이름 출력
df.columns

# df.info()

df['키'].min()
df['키'].max()
df['키'].mean()
df['키'].nlargest()
df['키'].nsmallest()

df['학교'].unique()  # unique - 중복제거 출력
df['학교'].nunique()  # unique - 중복제거 개수
df['SW특기'].count()  # null 값을 제외한 개수
df['학교'].count()

df['국어'].sum()
# Out:
# np.int64(500)

# %%
df.columns
df.columns[[0,3,-1]]
# Out:
# Index(['이름', '국어', 'SW특기'], dtype='object')

# %%
df[['이름','국어']]
df.columns[[1,3,5,-1]]
# Out:
# Index(['학교', '국어', '수학', 'SW특기'], dtype='object')
